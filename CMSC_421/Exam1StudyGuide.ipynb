# %% [markdown]
# # Study Guide Questions
#
# ## OS Structures
#
# What does a system call do
# - goes form user land to kernel land. How you access kernel resources.
#
# What is a system program
# - ls, find, which, grep. Things that are tied to the OS
#
# What is the imporance of having libraries
# - prgorammers ar lazy. there are plenty of people smarter than me writing code.
#
# What is the difference between A cpu and a core of a cpu.
# - A CPU is a physical unit. A cpu can have multiple cores, which execute instructions in parallel
#
# ## Processes
#
# What is a process. Define a process and a program
# - A process is a task that is running in an operating system. A program is dormant, while a process is active
#
# Understand stack, heap, data, text sections of virtual memory
# - Each process has virtual memory. Stack is for stoting parameters or recursion. HEaps are for allocating dynamic memory. Data section is or storing variables. Text is for storing code.
#
# Which states can a process reside in
# - State table. new, ready, Running, Waiting, Terminated
#
#
# What is a proces control block
# - a table storign all metadat about a process. Used as a bookwmakr when the os needs to save state progress and switch to another state.
#
# What is a contexts switch
# - When we switch processes using the process control block.
#
# Diff between fork exec and Waiting
# - fork duplicates process, exec replaces child process, wait has parent wait for chils to finish.
#
# How many process are running when you fork a process
# - 2. 2^n are created. 2^n - 1 have been created.
#
# What is a thread vs process
# Threads share address space. Process have their own virtual memory. Threads therefore require more careful programming as to not contaiminate eachothers data. Threads require less resources as well. Data is allocated on the stack since we are sharing all other sections of memory.
#
# Process ID
# - ID of the running process. Can find with ps -ef
#
# State Tables
# - same thing as the process states, no skipping steps
#
#
# Difference between a zombie and an orphan.
# -Zombie process are doing no work but havent been terminated, parent is dead. Orphanned processes have not been retireved by the parent. Orphaned proceeses will go up the family tree to next of kin.
#
# Shared memory vs messgae message passing
# - Shared memory has 2 processes using a buffer in user land writing and reading data fo and from each otehr. Requires synchronization between processes. Message passing has a queue in kernel land where programs can read and write when they are ready.
#
# Blocking vs Non Blocking:
# - some processes need to be finished before they allow other processes to continue. Like when a pipe is full and we want to send data strough it still. lucy and the chocolate factory
#
# Interprocess communication
# - Many programms require the aide of others to function.
#
# ##How are pipes used
#
# Te producer consumer problem
# - Lucy and the chocolate factory problem
#
#
# ## Threading
#
# Multicore vs multiprocessor
#
# - Multicore,more than one core, with parallelism. Multiprocessing is concurrency with time slicing in the off time. Can be done on a s single core machine
#
# What is hyper Threading
# - when cores have their own sets of register for one core. Each core can still only do one process per unit of time, but we can change proceses very quickly
#
# Signal Handling
# - NOT ON THE EXAM
#
# Difference between layers of cache
# - The higher the cache level, the more valueable the data, the quicker and smaller the cache cell.
#
#
# Concurrency vs parallelism
# - parallelism means processes are being executed in the same exact time. Parallelism is like multi core or multithreading processing.
#
# What is a thread pool.
# NOT ON EXAM
#
# Ahmdals Law
# Speed up with parallel and serial processes
#
# \proc
# Virtual mounted filesystem that contains data about processes.
