# %% [markdown]
# # Exam 2 Study Guide
#
# ## Chocolate key cryptography
# - Asymmetric Keys are used to exchange symmetric keys
# - Each user has a public and private key, sender encrypts message using recipients private key, and then the recipient decrypts the message using their own private key
#
#
# ## Signals, interrupts, and traps
# - signals come from software, interrupts come from hardware
# - polling is when we check intermitently if decived need servicing, interrupts send data to an interruot register and are checked after every intruction
# - signals are the software equivalent to hardware interrupts like ctrl+c
# ## Traps: what the fuck are they
#
#
# ## Scheduling and Dispatching
# - Scheduling is choosing which job comes next, dispatching gets job from scheduler, and dispatcher puts it in running queue
#
# - Criteria for Scheduling
# first come first serve, shortest job first, shortest remaining time first
#
#
# -multilevel queue means 5 processes queues are descending in priotiy, multilevel feedback queue same thing except jobs can change priority, jobs bubble up
#
# - mutex vs semaphore, mutex single holder lock, sephamore counts how many people are in line to get in
#
# - race conditions with threads
# - solution to critical section
#     - mutual exclusion
#     - progress
#     - bounded wait
#     ALl mist be true
#
#
# Deadlock - 2 processes waiting on signals that can only come from each other.
# Satrvation - hung process somewhere causing locked process to never be released
#
# Unix file system -
#
# GTP vs MBR
# 4 paritions, with files systems
#
# Different allocation methods for disk data
# - continuous
# -
#
#
# UMASK sets permission of file or directory upon creation. CHMOD changes it later
#
# taking permissions away from a file that is first created
# UMASK default is 0002, wr permission is taken away
#
# ACCESS control list
# - groups makes giving permissions to files easy
#
# Symbolic vs hard file linking
# - symbolic links link over filesystem
#
#
#
# Primary Vs Extended vs Logical Data Partitions
# - old school
# - primary is what you boot from
# - logical partitions hold extended partitions,
# - extended partitions hold files
#
# - steps to make usuable disck
#     - name disk
#     - partition
#     - make file system
#     - create mount point
#     - mount file system
#     - to make permanent generate file system table
#
#
# 4 primary partitions on a disk or 1 primary and 1 extended holding 3 logical
#
# Drives have names like /dev/SDA
#
# first primary partition is /dev/sda1
# first logical parition is  something like /dev/sda5
