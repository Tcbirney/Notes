# %% [markdown]
# # Operating Systems
#
# ## OS services
#
# provide env for execution of progs
# services are
# - UI
#     - CLI
#     - GUI
#     - Touch Screen
#     - Batch
#
# - Program Execution
#
# - I/O ops
#
# - File sys manipulation
#
# - Communication
#
#     - Communication may be shared via memory or through message passing (packets moved by the OS)
#
# - error detection
#
#     - May occur in the CPU, Hardware memory, I/O devices, User Program
#     - For each type of error, the OS should take the appropriate action to ensure correct and consistent computing
#
# - Resource Allocation
#
#     - Many jobs are running concurrently, divided into threads, so we must allocate resources accordingly
#
# - Logging
#
#     - To keep track of what users are using what kinds of resources
#
# - Protction and Security
#
#     - Protection
#
#         Involves ensuring all access to system resources is controlled
#
#     - Security
#
#         System access from outsiders required authentication. This extends to defending system I/O from invallid access attempts as well.
#
# # Definitely get the "View of Operating System Services" image

# %% [markdown]
# ## User Operated System Interfaces
#
# CLI or command line interface
#
# - Sometimes implemented by kernel, sometimes by system program
# - Multiple shell flavors (We use BASH)
#
# GUI or graphical user interface
#
# - user friendly desktop experience
#
#     - usually normal preipherals, mouse, keyboard
#     - icons
#
# - many systems have both a GUI and CLI

# %% [markdown]
# ## System Calls
#
# System calls are a __programming interface to the services__ provided by the OS. They are typically written in a high level language such as __C/C++__. They are usually accessed through an Application Programming Interface __(API)__, rather than being called directly.
#
#
# The most common APIs are WIN32 for Windows, __POSIX API__ for for POSIX based systems (so all UNIX, LINUX, and MAC OS systems), and JAVA API for for the Java Virtual Machine (JVM)
#
# There are numberous system calls to do something as simple as compying one file to another.
#
# ### Implementation
#
# Typycally there is a number associated with each system call, and there is a system call interface that maintains a table indexed according to those numbers. The system call interface is the barrier between user land and kernel land.
#
# ### System Call Parameter Passing
#
# A lot of times when calling system calls, more information is required that just the identity of the desired system call. And the information required may vary according to OS and language.
#
# Three general methods to pass parameters to OS
#
# 1. Simplest: Pass the parameters in registers. In some cases there may be more paramters than registers, so this wouldn't be feasible
#
# 2. Paramters are stored in a block or table in memory, and the address of the block is passed in as a paramter in a register.
#
# 3. Paramters are placed, or pushed onto the stack by the program, and popped off the stack by the operating system once they have been read.
#
# The block and stack methods do not limit the number or length of paramters that are passed
#
# ### What Kinds of system calls are there?
#
# Process control
# - Create, terminate process
# - End, abort
# - Load, execute
# - Get, process attribute
# - Wait for time
# - Wait event, single event
# - Allocate and free memory
# - Dump memory if error
# - Debugger for determining bugs, single step execution
# - Locks for managin access to shared data between processes
#
# File Management
# - Create, delete files
# - Open, close file
# - Read, write, reposition
# - get, set file attributes
#
# Device Management
# - Request, release device
# - Read, write, reposition
# - get, set device attributes
# - logically attach, detach devices
#
# Information Maintenance
# - Get, set time and date
# - Get, set system data
# - Get, set process, file, or device attributes
#
# Communications
# - Create, delete communication connection
# - Send, reviece messages
# - Shared memory model
# - Transfer status information
# - Attach, detach remote devices
#
# Protection
# - Control access to resources
# - Get, set permissions
# - Allow, deny user access

# %% [markdown]
# ## System Services
#
# System services __provide a convenient environment for program execution and development__
#
# - File Manipulation
#
#     This is where we can create, delete, copy, rename, print, dump, list, and generally manipulate files and directories
#
# - Status Information
#
#     Some system services here ask the sisyem for information like date, time, memory, disk space, or number of users. Others provide information such as performance, logging, and debugging information. These programs usually print output to the terminal or other output devices. Som systems implement a registry, which is used to store and retrieve configurtion information.
#
# - Programming Language Support
#
#     This encompasses compilers, assembers, and debuggers. Interpreters are sometimes provided by the OS.
#
# - Program Loading and Execution
# - Communications
# - Background Services
#
#     We have services that launch at boot time. They provide facilities like disk checking, process scheduling, error logging or printing. These things are used in the user context and not the kernel context. They are knwon as services, subsystems, and daemons.
#
# - Application Programs
#
#     These are not pertaining to the system at all. They are run by the user and are not considered part of the OS. Any common application that I run.

# %% [markdown]
# ## Linkers vs Loaders
#
# Source code is compiled into object files which are designed to be loaded into any physical memory location, which creates a relocatable object file. __Linkers__ combine these into a single binary executable file, and also brings in libraries.
#
# The code lies on secondary storage as a binary executable, where it is brought into memory by a loader to be executed.
#
# Most systems don't link libraries into executables. Dynamically linked libraries are libraries that are linked once and loaded as needed, as many subroutines may use the same libraries.
#
# ### get the linker loader chart

# %% [markdown]
# ## Why are some applications operating system specific?
#
# Apps compiled on one system are not usually compatible with apps compiled on another operating system because each operating system provides its own unique sytem calls.
#
# Some apps however are compatible across OSs because
#
# - They are written in an interpreted language like python, which has an interpreter availabale on all of these systems.
#
# - They are written in a langiage that includes a virtual machine containing the running app, like Java and the Java VM
#
# - They use a standard language like C, which can compile on each operating system
#
#
# The Application Binary Interface (ABI) is the architecture equivalent of the API which defines how different components of binary code can interface for a given operating system on a given architecture, CPU, etc

# %% [markdown]
# ## OS Design and Implementation
#
# The design process is not solvable, but some approaches are effective
#
# The internal structure of different OSs can vary widely. The design process is started with goals and specifications. This is affected by the choice of hardware and type of system. There are user goals and system goals.
#
# Emulation - allows programs to run by emulating the architeture of another cpu
