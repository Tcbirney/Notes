# %% [markdown]
# # Interrupts

# %% [markdown]
# an external event that causes a change in the normal execution of the intruction execution. Usually genrerated by hardware devices.\Interrupts are asynchronous with respect to the current process. The process can not determine when the next interrupt will happem.
#
# Signals are generated by processes running in the computer.
#
# but we want the cpu to stay busy
